# %% [markdown]
# ### Not Final Version
# This notebook doesn't contain the final version of the model and relevant training image generator implementations.

# %% [markdown]
# ### Model (Without ResNet)
# * Aggresive+ Moderate downsampling
# * Skip connections for concatenation
# * RELU + Batch Norm
# * No RELU after each block output
# * Multi-scale feature extraction using ASPP similar network
# * Dilated Asymmetric Separable Convolutional layer

# %%
import sys
import random
import os
import warnings

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain

from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras import models
from tensorflow.keras import backend as K
from tensorflow.keras import callbacks
import glob

from PIL import Image
import glob

import tensorflow as tf
import time
import cv2

# %%
# !which python3
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    print("Name:", gpu.name, "  Type:", gpu.device_type)
# Out:
# which: no python3 in (/d/ANACONDA/envs/CondaTF:/d/ANACONDA/envs/CondaTF/Library/mingw-w64/bin:/d/ANACONDA/envs/CondaTF/Library/usr/bin:/d/ANACONDA/envs/CondaTF/Library/bin:/d/ANACONDA/envs/CondaTF/Scripts:/d/ANACONDA/envs/CondaTF/bin:D:/ANACONDA:D:/ANACONDA/Library/mingw-w64/bin:D:/ANACONDA/Library/usr/bin:D:/ANACONDA/Library/bin:D:/ANACONDA/Scripts:D:/ANACONDA/bin:D:/ANACONDA/Scripts/condabin:/c/Users/Tom Zhou/bin:/mingw64/bin:/usr/local/bin:/usr/bin:/usr/bin:/mingw64/bin:/usr/bin:/c/Users/Tom Zhou/bin:/d/Softwares/python_27:/d/Softwares/python_27/Scripts:/d/Softwares/python_37/Scripts:/d/Softwares/python_37:/c/windows/system32:/c/windows:/c/windows/System32/Wbem:/c/windows/System32/WindowsPowerShell/v1.0:/c/windows/System32/OpenSSH:/c/Program Files (x86)/NVIDIA Corporation/PhysX/Common:/c/Program Files/Intel/WiFi/bin:/c/Program Files/Common Files/Intel/WirelessCommon:/d/Softwares/Matlab2016/bin:/d/Softwares/matlab2016a/runtime/win64:/d/Softwares/matlab2016a/bin:/d/Softwares/matlab2016a/polyspace/bin:/c/Program Files/NVIDIA Corporation/NVIDIA NvDLISR:/c/Program Files (x86)/Windows Kits/8.1/Windows Performance Toolkit:/cmd:/c/Program Files (x86)/Calibre2:/c/Program Files (x86)/QuickTime/QTSystem:/c/Program Files/PuTTY:/d/ANACONDA:/d/ANACONDA/Library/mingw-w64/bin:/d/ANACONDA/Library/usr/bin:/d/ANACONDA/Library/bin:/d/ANACONDA/Scripts:/c/Users/Tom Zhou/AppData/Local/Microsoft/WindowsApps:/c/Program Files/Bandizip:/d/IntelliJ IDEA Community Edition 2018.3/bin:/c/Users/Tom Zhou/AppData/Local/Programs/Microsoft VS Code/bin:/d/Softwares/underPath:/d/Softwares/MikTex/miktex/bin/x64:/usr/bin/vendor_perl:/usr/bin/core_perl)
# Name: /physical_device:GPU:0   Type: GPU

# %%
# Set some parameters
IMG_WIDTH = 512
IMG_HEIGHT = 512
IMG_CHANNELS = 3
#TRAIN_PATH = './dataset/training/'
#TEST_PATH = './dataset/testing/'
# TRAIN_NUM = 1700
# TEST_NUM = 300
sample_dir = "../NewDataset/train/img/"
mask_dir = "../NewDataset/train/mask/"
test_sample_dir = "../dataset_kaggle/testing/sample/"
test_mask_dir = "../dataset_kaggle/testing/mask/"

# %%
#Get the filenames of training and testing data
sample_ids = None
test_sample_ids = None
sample_ids = next(os.walk(sample_dir))[2]
test_sample_ids = next(os.walk(test_sample_dir))[2]
print(sample_ids[:10])
print(test_sample_ids[:10])
# Out:
# ['1803151818-00000003.png', '1803151818-00000004.png', '1803151818-00000006.png', '1803151818-00000007.png', '1803151818-00000008.png', '1803151818-00000009.png', '1803151818-00000010.png', '1803151818-00000012.png', '1803151818-00000015.png', '1803151818-00000017.png']
# ['00001.png', '00002.png', '00003.png', '00004.png', '00005.png', '00006.png', '00007.png', '00008.png', '00009.png', '00010.png']

# %%
def dilated_conv_block(input_tensor, num_filters):
    '''
    Number of filters (num_filters) : the number of input and output channels.
        the block doesn't change output shape
    
    NOTE
        set the the depth separable convolution's filter_num to different sizes
            and see how the parameters change.

    '''
    # Direct 1x1 convolution
    encoderONE = layers.Conv2D(int(num_filters/4), (1,1), padding = "same", use_bias=False)(input_tensor)
    encoderONE = layers.BatchNormalization()(encoderONE)
    encoderONE = layers.Activation('relu')(encoderONE)
    
    #1x1 convolution
    encoderTWO = layers.Conv2D(int(num_filters/2), (1,1), padding = "same", use_bias=False)(input_tensor)
    # 5x5 depthwise separable convolution stride 1 dilation_rate = 2
    encoderTWO = layers.SeparableConv2D(int(num_filters/4), (5,5), dilation_rate = 2, padding = "same", use_bias=False, depth_multiplier=2)(encoderTWO)
    encoderTWO = layers.BatchNormalization()(encoderTWO)
    encoderTWO = layers.Activation('relu')(encoderTWO)
    
    #1x1 convolution
    encoderTHR = layers.Conv2D(int(num_filters/2), (1,1), padding = "same", use_bias=False)(input_tensor)
    # 3x3 depthwise separable convolution stride 1 dilation_rate = 2
    encoderTHR = layers.SeparableConv2D(int(num_filters/4), (3,3), dilation_rate = 2, padding = "same", use_bias=False, depth_multiplier=2)(encoderTHR)
    encoderTHR = layers.BatchNormalization()(encoderTHR)
    encoderTHR = layers.Activation('relu')(encoderTHR)
    
    #1x1 convolution
    encoderFOUR = layers.Conv2D(int(num_filters/2), (1,1), padding = "same", use_bias=False)(input_tensor)
    # 5x5 depthwise separable convolution stride 1 dilation_rate = 2
    encoderFOUR = layers.SeparableConv2D(int(num_filters/4), (5,5), dilation_rate = 3, padding = "same", use_bias=False, depth_multiplier=2)(encoderFOUR)
    encoderFOUR = layers.BatchNormalization()(encoderFOUR)
    encoderFOUR = layers.Activation('relu')(encoderFOUR)
    
    encoderOUT = layers.concatenate([encoderFOUR,encoderTHR, encoderTWO, encoderONE], axis=-1)
    #Final 1x1 convolution with relu to make sure the output have the same channels as input
#     encoderOUT = layers.Conv2D(num_filters, (1,1), padding = "same", use_bias=False)(encoderOUT)
#     encoderOUT = layers.Activation("relu")(encoderOUT)

    return encoderOUT

def downsample_block(input_tensor, num_filters):
    
    #Store the input to this "max_pooling layer" for skip connections
    store_feature =  layers.Conv2D(int(num_filters/4), (1,1), padding = "same", use_bias=False)(input_tensor)
    
    encoder = layers.Conv2D(int(num_filters/2), (1,1), padding = "same", use_bias=False)(input_tensor)
    
    # 2x2 max_pooling with stride 2
    encoderONE = layers.MaxPooling2D((2, 2), strides=(2, 2))(input_tensor) #already have output dimension desired

    # 5x5 depthwise separable convolution stride = 2
    encoderTWO = layers.ZeroPadding2D(padding=(2, 2))(encoder) # zero-padding (2,2) to keep output dimension consistent
    encoderTWO = layers.SeparableConv2D(num_filters, (5,5), strides = 2, use_bias=False)(encoderTWO)
    encoderTWO = layers.BatchNormalization()(encoderTWO)
    encoderTWO = layers.Activation('relu')(encoderTWO)
    
    # 3x3 depthwise separable convolution stride = 2
    encoderTHR = layers.ZeroPadding2D(padding = (1,1))(encoder) # zero-padding (1,1) to keep output dimension consistent
    encoderTHR = layers.SeparableConv2D(num_filters, (3,3), strides = 2, use_bias=False)(encoderTHR)
    encoderTHR = layers.BatchNormalization()(encoderTHR)
    encoderTHR = layers.Activation('relu')(encoderTHR) 

    
    # 7x7 depthwise separable convolution stride = 2
    encoderFOUR = layers.ZeroPadding2D(padding=(3, 3))(encoder) # zero-padding (3,3)to keep output dimension consistent
    encoderFOUR = layers.SeparableConv2D(num_filters, (7,7), strides = 2, use_bias=False)(encoderFOUR)
    encoderFOUR = layers.BatchNormalization()(encoderFOUR)
    encoderFOUR = layers.Activation('relu')(encoderFOUR)
 
    #By now the encoderOUT has shape reduced to 1/2 of input shape
    encoderOUT = layers.concatenate([encoderFOUR, encoderTHR, encoderTWO, encoderONE], axis=-1)
    #Final 1x1 convolution with relu to make sure the output have 2 times channels as input
    encoderOUT = layers.Conv2D(num_filters*2, (1,1), padding = "same", use_bias=False)(encoderOUT)
    encoderOUT = layers.Activation("relu")(encoderOUT)
    
    return store_feature, encoderOUT

def decoder_block(input_tensor, concat_tensor, num_filters):
    
    decoder = layers.Conv2DTranspose(num_filters, (2, 2), strides=(2, 2), padding='same')(input_tensor)
    
    decoder = layers.concatenate([concat_tensor, decoder], axis=-1)
    decoder = layers.BatchNormalization()(decoder)
    decoder = layers.Activation('relu')(decoder)
    
    decoder = layers.SeparableConv2D(num_filters, (3, 3), padding='same')(decoder)
    decoder = layers.BatchNormalization()(decoder)
    decoder = layers.Activation('relu')(decoder)
    
#     decoder = layers.SeparableConv2D(num_filters, (3, 3), padding='same')(decoder)
#     decoder = layers.BatchNormalization()(decoder)
#     decoder = layers.Activation('relu')(decoder)
    return decoder

# %%
img_shape = (IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)
print(img_shape)

inputs = layers.Input(shape=img_shape)
initial_block_2 = layers.MaxPool2D((2,2), strides = 2)(inputs)

#Now modify the inputs
initial_block_1 = layers.ZeroPadding2D(padding = (1,1))(inputs)
initial_block_1 = layers.Conv2D(29, (3,3), strides = 2, use_bias = False)(initial_block_1)

initial_block = layers.concatenate([initial_block_1, initial_block_2], axis = -1)

# 256
encoder0 = dilated_conv_block(initial_block, 32)
encoder0, encoder0_pool = downsample_block(encoder0, 32)

# 128
encoder1 = dilated_conv_block(encoder0_pool, 64)
encoder1, encoder1_pool = downsample_block(encoder1, 64)

# 64
encoder2 = dilated_conv_block(encoder1_pool, 128)
encoder2, encoder2_pool = downsample_block(encoder2, 128)

# 32
encoder3 = dilated_conv_block(encoder2_pool, 256)
encoder3, encoder3_pool = downsample_block(encoder3, 256)

# 16
# encoder4 = dilated_conv_block(encoder3_pool, 512)
# encoder4, encoder4_pool = downsample_block(encoder4, 512)

# 8
center = dilated_conv_block(encoder3_pool, 512)
center = dilated_conv_block(center, 512)

# center


# 16
decoder3 = decoder_block(center, encoder3, 256)
# 32
decoder2 = decoder_block(decoder3, encoder2, 128)
# 64
decoder1 = decoder_block(decoder2, encoder1, 64)
# 128
decoder0 = decoder_block(decoder1, encoder0, 32)
# 256
final = layers.UpSampling2D((2,2), interpolation= "bilinear")(decoder0)
outputs = layers.Conv2D(1, (1, 1), activation='sigmoid')(final)

model = None
model = models.Model(inputs=[inputs], outputs=[outputs])

model.summary()
# Out:
# (512, 512, 3)
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 512, 512, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 514, 514, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 29) 783         zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 256, 256, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 256, 256, 32) 0           conv2d_1[0][0]
#                                                                  max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 256, 256, 16) 512         concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 256, 256, 16) 512         concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 256, 256, 16) 512         concatenate_1[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_2 (SeparableCo (None, 256, 256, 8)  1056        conv2d_5[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_1 (SeparableCo (None, 256, 256, 8)  544         conv2d_4[0][0]
# __________________________________________________________________________________________________
# separable_conv2d (SeparableConv (None, 256, 256, 8)  1056        conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 256, 8)  256         concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 256, 256, 8)  32          separable_conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 256, 256, 8)  32          separable_conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 8)  32          separable_conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 8)  32          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 256, 256, 8)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 256, 256, 8)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256, 256, 8)  0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 256, 256, 8)  0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 256, 256, 32) 0           activation_3[0][0]
#                                                                  activation_2[0][0]
#                                                                  activation_1[0][0]
#                                                                  activation[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 256, 256, 16) 512         concatenate_2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 262, 262, 16) 0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 258, 258, 16) 0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 260, 260, 16) 0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_5 (SeparableCo (None, 128, 128, 32) 1296        zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_4 (SeparableCo (None, 128, 128, 32) 656         zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_3 (SeparableCo (None, 128, 128, 32) 912         zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 128, 128, 32) 128         separable_conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 128, 128, 32) 128         separable_conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 128, 128, 32) 128         separable_conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 128, 128, 32) 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 128, 128, 32) 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 128, 128, 32) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 128, 128, 32) 0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 128 0           activation_6[0][0]
#                                                                  activation_5[0][0]
#                                                                  activation_4[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 128, 128, 64) 8192        concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 128, 128, 64) 0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 128, 128, 32) 2048        activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 128, 128, 32) 2048        activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 128, 128, 32) 2048        activation_7[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_8 (SeparableCo (None, 128, 128, 16) 2624        conv2d_12[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_7 (SeparableCo (None, 128, 128, 16) 1600        conv2d_11[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_6 (SeparableCo (None, 128, 128, 16) 2624        conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 128, 128, 16) 1024        activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 128, 128, 16) 64          separable_conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 128, 128, 16) 64          separable_conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 128, 128, 16) 64          separable_conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 128, 128, 16) 64          conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 128, 128, 16) 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 128, 128, 16) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 128, 128, 16) 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 128, 128, 16) 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 128, 128, 64) 0           activation_11[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_9[0][0]
#                                                                  activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 128, 32) 2048        concatenate_4[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_7 (ZeroPadding2D (None, 134, 134, 32) 0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 130, 130, 32) 0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 132, 132, 32) 0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_11 (SeparableC (None, 64, 64, 64)   3616        zero_padding2d_7[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_10 (SeparableC (None, 64, 64, 64)   2336        zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_9 (SeparableCo (None, 64, 64, 64)   2848        zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 64, 64, 64)   256         separable_conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 64, 64, 64)   256         separable_conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 64, 64, 64)   256         separable_conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 64, 64, 64)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 64, 64, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 64, 64, 64)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 64, 64, 64)   0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 256)  0           activation_14[0][0]
#                                                                  activation_13[0][0]
#                                                                  activation_12[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 128)  32768       concatenate_5[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 64, 64, 128)  0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 64, 64, 64)   8192        activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 64, 64)   8192        activation_15[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 64, 64)   8192        activation_15[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_14 (SeparableC (None, 64, 64, 32)   7296        conv2d_19[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_13 (SeparableC (None, 64, 64, 32)   5248        conv2d_18[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_12 (SeparableC (None, 64, 64, 32)   7296        conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 32)   4096        activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 64, 64, 32)   128         separable_conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 64, 64, 32)   128         separable_conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64, 64, 32)   128         separable_conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 64, 64, 32)   128         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 64, 64, 32)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 64, 64, 32)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 64, 64, 32)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 64, 64, 32)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 64, 64, 128)  0           activation_19[0][0]
#                                                                  activation_18[0][0]
#                                                                  activation_17[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 64, 64, 64)   8192        concatenate_6[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_10 (ZeroPadding2 (None, 70, 70, 64)   0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_9 (ZeroPadding2D (None, 66, 66, 64)   0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_8 (ZeroPadding2D (None, 68, 68, 64)   0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_17 (SeparableC (None, 32, 32, 128)  11328       zero_padding2d_10[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_16 (SeparableC (None, 32, 32, 128)  8768        zero_padding2d_9[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_15 (SeparableC (None, 32, 32, 128)  9792        zero_padding2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 32, 32, 128)  512         separable_conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 32, 32, 128)  512         separable_conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 32, 32, 128)  512         separable_conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 32, 32, 128)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 32, 32, 128)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 32, 32, 128)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 32, 32, 128)  0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 32, 32, 512)  0           activation_22[0][0]
#                                                                  activation_21[0][0]
#                                                                  activation_20[0][0]
#                                                                  max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 32, 32, 256)  131072      concatenate_7[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 32, 32, 256)  0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 32, 32, 128)  32768       activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 32, 32, 128)  32768       activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 32, 32, 128)  32768       activation_23[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_20 (SeparableC (None, 32, 32, 64)   22784       conv2d_26[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_19 (SeparableC (None, 32, 32, 64)   18688       conv2d_25[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_18 (SeparableC (None, 32, 32, 64)   22784       conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 32, 32, 64)   16384       activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 32, 32, 64)   256         separable_conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 32, 32, 64)   256         separable_conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 32, 32, 64)   256         separable_conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 32, 32, 64)   256         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 32, 32, 64)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 32, 32, 64)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 32, 32, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 32, 32, 64)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 32, 32, 256)  0           activation_27[0][0]
#                                                                  activation_26[0][0]
#                                                                  activation_25[0][0]
#                                                                  activation_24[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 32, 32, 128)  32768       concatenate_8[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_13 (ZeroPadding2 (None, 38, 38, 128)  0           conv2d_28[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_12 (ZeroPadding2 (None, 34, 34, 128)  0           conv2d_28[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_11 (ZeroPadding2 (None, 36, 36, 128)  0           conv2d_28[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_23 (SeparableC (None, 16, 16, 256)  39040       zero_padding2d_13[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_22 (SeparableC (None, 16, 16, 256)  33920       zero_padding2d_12[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_21 (SeparableC (None, 16, 16, 256)  35968       zero_padding2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 16, 16, 256)  1024        separable_conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 16, 16, 256)  1024        separable_conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 16, 16, 256)  1024        separable_conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 16, 16, 256)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 16, 16, 256)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 16, 16, 256)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 16, 16, 256)  0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 16, 16, 1024) 0           activation_30[0][0]
#                                                                  activation_29[0][0]
#                                                                  activation_28[0][0]
#                                                                  max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 16, 16, 512)  524288      concatenate_9[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 16, 16, 512)  0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 16, 16, 256)  131072      activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 16, 16, 256)  131072      activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 16, 16, 256)  131072      activation_31[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_26 (SeparableC (None, 16, 16, 128)  78336       conv2d_33[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_25 (SeparableC (None, 16, 16, 128)  70144       conv2d_32[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_24 (SeparableC (None, 16, 16, 128)  78336       conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 16, 16, 128)  65536       activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 16, 16, 128)  512         separable_conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 16, 16, 128)  512         separable_conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 16, 16, 128)  512         separable_conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 16, 16, 128)  512         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 16, 16, 128)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 16, 16, 128)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 16, 16, 128)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 16, 16, 128)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 16, 16, 512)  0           activation_35[0][0]
#                                                                  activation_34[0][0]
#                                                                  activation_33[0][0]
#                                                                  activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 16, 16, 256)  131072      concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 16, 16, 256)  131072      concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 16, 16, 256)  131072      concatenate_10[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_29 (SeparableC (None, 16, 16, 128)  78336       conv2d_37[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_28 (SeparableC (None, 16, 16, 128)  70144       conv2d_36[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_27 (SeparableC (None, 16, 16, 128)  78336       conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 16, 16, 128)  65536       concatenate_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 16, 16, 128)  512         separable_conv2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 16, 16, 128)  512         separable_conv2d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 16, 16, 128)  512         separable_conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 16, 16, 128)  512         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 16, 16, 128)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 16, 16, 128)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 16, 16, 128)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 16, 16, 128)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 16, 16, 512)  0           activation_39[0][0]
#                                                                  activation_38[0][0]
#                                                                  activation_37[0][0]
#                                                                  activation_36[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 32, 32, 64)   16384       concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 32, 32, 256)  524544      concatenate_11[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 32, 32, 320)  0           conv2d_27[0][0]
#                                                                  conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 32, 32, 320)  1280        concatenate_12[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 32, 32, 320)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_30 (SeparableC (None, 32, 32, 256)  85056       activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 32, 32, 256)  1024        separable_conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 32, 32, 256)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 64, 64, 32)   4096        concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 64, 64, 128)  131200      activation_41[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 64, 64, 160)  0           conv2d_20[0][0]
#                                                                  conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 64, 64, 160)  640         concatenate_13[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 64, 64, 160)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_31 (SeparableC (None, 64, 64, 128)  22048       activation_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 64, 64, 128)  512         separable_conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 64, 64, 128)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 128, 128, 16) 1024        concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 128, 128, 64) 32832       activation_43[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 128, 128, 80) 0           conv2d_13[0][0]
#                                                                  conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 128, 128, 80) 320         concatenate_14[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 128, 128, 80) 0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_32 (SeparableC (None, 128, 128, 64) 5904        activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 128, 128, 64) 256         separable_conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 128, 128, 64) 0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 256, 256, 8)  256         concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 256, 256, 32) 8224        activation_45[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 256, 256, 40) 0           conv2d_6[0][0]
#                                                                  conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 256, 256, 40) 160         concatenate_15[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 256, 256, 40) 0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_33 (SeparableC (None, 256, 256, 32) 1672        activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 256, 256, 32) 128         separable_conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 256, 256, 32) 0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 512, 512, 32) 0           activation_47[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 512, 512, 1)  33          up_sampling2d[0][0]
# ==================================================================================================
# Total params: 3,357,528
# Trainable params: 3,349,480
# Non-trainable params: 8,048
# __________________________________________________________________________________________________

# %%
def dice_coeff(y_true, y_pred):
    smooth = 1.
    # Flatten
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    score = (2. * intersection + smooth) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth)
    return score

def dice_loss(y_true, y_pred):
    loss = 1 - dice_coeff(y_true, y_pred)
    return loss

def bce_dice_loss(y_true, y_pred):
    loss = losses.binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)
    return loss

# %%
def castF(x):
    return K.cast(x, K.floatx())

def castB(x):
    return K.cast(x, bool)

def iou_loss_core(true,pred):  #this can be used as a loss if you make it negative
    intersection = true * pred
    notTrue = 1 - true
    union = true + (notTrue * pred)

    return (K.sum(intersection, axis=-1) + K.epsilon()) / (K.sum(union, axis=-1) + K.epsilon())

def competitionMetric2(true, pred): #any shape can go - can't be a loss function

    tresholds = [0.5 + (i*.05)  for i in range(10)]

    #flattened images (batch, pixels)
    true = K.batch_flatten(true)
    pred = K.batch_flatten(pred)
    pred = castF(K.greater(pred, 0.5))

    #total white pixels - (batch,)
    trueSum = K.sum(true, axis=-1)
    predSum = K.sum(pred, axis=-1)

    #has mask or not per image - (batch,)
    true1 = castF(K.greater(trueSum, 1))    
    pred1 = castF(K.greater(predSum, 1))

    #to get images that have mask in both true and pred
    truePositiveMask = castB(true1 * pred1)

    #separating only the possible true positives to check iou
    testTrue = tf.boolean_mask(true, truePositiveMask)
    testPred = tf.boolean_mask(pred, truePositiveMask)

    #getting iou and threshold comparisons
    iou = iou_loss_core(testTrue,testPred) 
    truePositives = [castF(K.greater(iou, tres)) for tres in tresholds]

    #mean of thressholds for true positives and total sum
    truePositives = K.mean(K.stack(truePositives, axis=-1), axis=-1)
    truePositives = K.sum(truePositives)

    #to get images that don't have mask in both true and pred
    trueNegatives = (1-true1) * (1 - pred1) # = 1 -true1 - pred1 + true1*pred1
    trueNegatives = K.sum(trueNegatives) 

    return (truePositives + trueNegatives) / castF(K.shape(true)[0])

# %%
save_model_path = './weights.hdf5'
cp = tf.keras.callbacks.ModelCheckpoint(filepath=save_model_path, monitor='val_loss', save_best_only=True, verbose=1)

# %%
batch_size = 6

class DataGenerator(tf.keras.utils.Sequence):
#     'Generates data for Keras'
    def __init__(self, train_im_path=sample_dir,train_mask_path=mask_dir,
                 augmentations=None, batch_size=batch_size,img_size=512, n_channels=3, shuffle=True, mode="train"):
#         'Initialization'
        self.batch_size = batch_size
        self.train_im_paths = glob.glob(train_im_path+'*')
#         print(self.train_im_paths[:10])
        
        self.train_im_path = train_im_path
        self.train_mask_path = train_mask_path

        self.img_size = img_size
        
        self.n_channels = n_channels
        self.shuffle = shuffle
        self.augment = augmentations
        self.mode = mode

        self.on_epoch_end()

    def __len__(self):
#         'Denotes the number of batches per epoch'
        return int(np.ceil(len(self.train_im_paths) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:min((index+1)*self.batch_size,len(self.train_im_paths))]

        # Find list of IDs
        list_IDs_im = [self.train_im_paths[k] for k in indexes]
    
#         print(list_IDs_im[:10])
        # Generate data
        X, y = self.data_generation(list_IDs_im)

        # First generate data
        #Then rescale them
 
        if self.augment is None:
            return X.astype(np.float32)/255,np.array(y).astype(np.float32)/255
        else:            
            im,mask = [],[]   
            for x,y in zip(X,y):
                augmented = self.augment(image=x, mask=y)
                aug_im = augmented['image']
                aug_mask = augmented['mask']
#                 print("augmented image data type:", aug_im.dtype)
#                 print("augmented mask data type:", aug_mask.dtype)
                im.append(augmented['image'])
                mask.append(augmented['mask'])
                
                return_im = np.array(im)
                return_mask = np.array(mask)
                return_im = return_im.astype(np.float32)/255
                return_mask = return_mask.astype(np.float32)/255
                
            return return_im, return_mask

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.train_im_paths))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def data_generation(self, list_IDs_im):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        # Initialization
        X = np.empty((len(list_IDs_im),self.img_size,self.img_size, self.n_channels))
        y = np.empty((len(list_IDs_im),self.img_size,self.img_size, 1))
        # Generate data
        for i, im_path in enumerate(list_IDs_im):
            
            im = cv2.imread(im_path)
            im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
#             print()
#             print(self.train_im_path)
#             print(self.train_mask_path)
#             print()
            
            # In the case of some file systems, the [:-1] must be added
            # IT'S VERY IMPORTANT, OTHERWISE THE REPLACEMENT WILL FAIL
            mask_path = im_path.replace(self.train_im_path[:-1], self.train_mask_path[:-1])
            if self.mode == "train":
                pass
            else:
                mask_path = mask_path[:-4]+"_matte.png"
            print(im_path)
            print(mask_path)
            mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
            
#             print("img data type:", im.dtype)
#             print("mask data type: ", mask.dtype)
#             print("img feed in: ", im[150:160, 150:160])
#             print("mask feed in: ", mask[150:160, 150:160])
            
            if len(im.shape)==2:
                print("shape before:", im.shape)
                im = np.repeat(im[...,None],3,2)
                print("shape after:",im.shape)
                
#             # Resize sample
            X[i,] = cv2.resize(im,(self.img_size,self.img_size))
#             X[i,] = resize(im,(800, 500))
            y[i,] = cv2.resize(mask,(self.img_size,self.img_size))[..., np.newaxis]
#             print("img after reszie:", im.dtype)
#             print("mask after resize: ", mask.dtype)

            #NOTE that after skimage.transform.resize, the pixel value range of
            #the mask is already between 0 and 1. No NEED TO DIVIDE by 255
            # BUT NOW USING cv2.resize(), the values are between 0 and 255
            y[y>64] = 255
            y[y <64] = 0
        
        return X,y

# %%
from albumentations import (
    Compose, HorizontalFlip, CLAHE, HueSaturationValue,
    RandomBrightness, RandomContrast, RandomGamma,OneOf,
    ToFloat, ShiftScaleRotate,GridDistortion, ElasticTransform, JpegCompression, HueSaturationValue,
    RGBShift, RandomBrightness, RandomContrast, Blur, MotionBlur, MedianBlur, GaussNoise,CenterCrop,
    IAAAdditiveGaussianNoise,GaussNoise,OpticalDistortion,RandomSizedCrop
)

AUGMENTATIONS_TRAIN = Compose([
    HorizontalFlip(p=0.7),
    OneOf([
        RandomGamma(gamma_limit=(90,100), p=0.5)
         ], p=0.6),
    OneOf([
        ElasticTransform(p =0.7),
        GridDistortion(num_steps=2, distort_limit=0.3,p=0.5),
#         OpticalDistortion(distort_limit=2, shift_limit=0.2),
        ], p=0.9)
#     ToFloat(max_value=1)
],p=1)


AUGMENTATIONS_TEST = Compose([
#     ToFloat(max_value=1)
],p=1)

# %%
a = DataGenerator(batch_size=10,shuffle=False, augmentations=AUGMENTATIONS_TRAIN)
gen_images,gen_masks = a.__getitem__(0)
max_images = 10
grid_width = 2

print()
print("-----------------------------------------")
print()
for i in range(10):
#     img = gen_images[i].astype(np.uint8)

    img = gen_images[i]
    gt = gen_masks[i]

#     print(img.shape)
#     print(gt.shape)
    
#     print("img dtype:")
#     print(img.dtype)
    
#     print("mask dtype:")
#     print(gt.dtype)
    
    
    plt.imshow(img)
#     print(img[200:230, 200:240])
    plt.show()

    plt.imshow(gt.squeeze(), cmap = "Greys")
#     print(gt.squeeze()[200:230, 200:240])
    plt.show()
# Out:
# ../NewDataset/train/img\1803151818-00000003.png
# ../NewDataset/train/mask\1803151818-00000003.png
# ../NewDataset/train/img\1803151818-00000004.png
# ../NewDataset/train/mask\1803151818-00000004.png
# ../NewDataset/train/img\1803151818-00000006.png
# ../NewDataset/train/mask\1803151818-00000006.png
# ../NewDataset/train/img\1803151818-00000007.png
# ../NewDataset/train/mask\1803151818-00000007.png
# ../NewDataset/train/img\1803151818-00000008.png
# ../NewDataset/train/mask\1803151818-00000008.png
# ../NewDataset/train/img\1803151818-00000009.png
# ../NewDataset/train/mask\1803151818-00000009.png
# ../NewDataset/train/img\1803151818-00000010.png
# ../NewDataset/train/mask\1803151818-00000010.png
# ../NewDataset/train/img\1803151818-00000012.png
# ../NewDataset/train/mask\1803151818-00000012.png
# ../NewDataset/train/img\1803151818-00000015.png
# ../NewDataset/train/mask\1803151818-00000015.png
# ../NewDataset/train/img\1803151818-00000017.png
# ../NewDataset/train/mask\1803151818-00000017.png
#
# -----------------------------------------

# %%
# Here the two generators are instantiated to fit in the model.fit_generator()
batchSize = 12
print(sample_dir)
print(mask_dir)
print(test_sample_dir)
print(test_mask_dir)
training_generator = DataGenerator(batch_size= batchSize, augmentations=AUGMENTATIONS_TRAIN,img_size=IMG_HEIGHT, mode = "train")

validation_generator = DataGenerator(batch_size=batchSize,train_im_path = test_sample_dir ,
                                     train_mask_path=test_mask_dir,
                                     augmentations=None,
                                     img_size=IMG_HEIGHT,
                                    mode = "test")
# Out:
# ./train/img/
# ./train/mask/
# ./testing/sample/
# ./testing/mask/

# %%
opt = tf.keras.optimizers.Adam(lr =0.002)
model.compile(optimizer=opt, loss=bce_dice_loss, metrics=[dice_loss, competitionMetric2])

# %%
model = models.load_model("./weights.hdf5", custom_objects={'bce_dice_loss': bce_dice_loss,
                                                           'dice_loss': dice_loss})

# %%
#already trained for 65 epochs

history = model.fit_generator(training_generator,
                    epochs=5,
                    validation_data = validation_generator,
                    callbacks=[cp],
                    verbose =1,
                    workers=8
                    )
# Out:
# Epoch 1/5
# 168/866 [====>.........................] - ETA: 12:14 - loss: 0.0414 - dice_loss: 0.0117
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:112: RuntimeWarning: invalid value encountered in greater
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:113: RuntimeWarning: invalid value encountered in less
# 865/866 [============================>.] - ETA: 0s - loss: 0.0425 - dice_loss: 0.0120
# Epoch 00001: val_loss improved from inf to 0.09049, saving model to ./weights.hdf5
# 866/866 [==============================] - 947s 1s/step - loss: 0.0425 - dice_loss: 0.0120 - val_loss: 0.0905 - val_dice_loss: 0.0215
# Epoch 2/5
# 865/866 [============================>.] - ETA: 0s - loss: 0.0421 - dice_loss: 0.0120
# Epoch 00002: val_loss did not improve from 0.09049
# 866/866 [==============================] - 862s 995ms/step - loss: 0.0421 - dice_loss: 0.0120 - val_loss: 0.1092 - val_dice_loss: 0.0255
# Epoch 3/5
# 865/866 [============================>.] - ETA: 0s - loss: 0.0423 - dice_loss: 0.0121
# Epoch 00003: val_loss did not improve from 0.09049
# 866/866 [==============================] - 863s 996ms/step - loss: 0.0424 - dice_loss: 0.0121 - val_loss: 0.1191 - val_dice_loss: 0.0246
# Epoch 4/5
# 865/866 [============================>.] - ETA: 0s - loss: 0.0403 - dice_loss: 0.0115
# Epoch 00004: val_loss did not improve from 0.09049
# 866/866 [==============================] - 854s 986ms/step - loss: 0.0403 - dice_loss: 0.0115 - val_loss: 0.1018 - val_dice_loss: 0.0216
# Epoch 5/5
# 865/866 [============================>.] - ETA: 0s - loss: 0.0401 - dice_loss: 0.0114
# Epoch 00005: val_loss improved from 0.09049 to 0.08746, saving model to ./weights.hdf5
# 866/866 [==============================] - 866s 999ms/step - loss: 0.0401 - dice_loss: 0.0114 - val_loss: 0.0875 - val_dice_loss: 0.0199

# %%
model.save("./v2_maybe_overfitting.hdf5")

# %%
test_generator = DataGenerator(batch_size=1,train_im_path = test_sample_dir ,
                                     train_mask_path=test_mask_dir,
                                     augmentations=None,
                                     img_size=IMG_HEIGHT,
                                    mode = "test")

# %%
test_img = np.zeros([10, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS])
test_mask = np.zeros([10, IMG_HEIGHT, IMG_WIDTH, 1])

for i in range(10):
    imgs, masks = test_generator.__getitem__(i)
    img = imgs[0]
    mask = masks[0]
    plt.imshow(img)
    plt.show()
    plt.imshow(mask[:,:,0], cmap = "Greys")
    plt.show()
    test_img[i] = img
    test_mask[i] = mask
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-26-85aaae89020d> in <module>
#       3
#       4 for i in range(10):
# ----> 5     imgs, masks = test_generator.__getitem__(i)
#       6     img = imgs[0]
#       7     mask = masks[0]
#
# <ipython-input-22-f9e9d012fd1a> in __getitem__(self, index)
#      39
#      40         # Generate data
# ---> 41         X, y = self.data_generation(list_IDs_im)
#      42
#      43 #         for i in range(batch_size):
#
# <ipython-input-22-f9e9d012fd1a> in data_generation(self, list_IDs_im)
#     103             X[i,] = cv2.resize(im,(self.img_size,self.img_size))
#     104 #             X[i,] = resize(im,(800, 500))
# --> 105             y[i,] = cv2.resize(mask,(self.img_size,self.img_size))[..., np.newaxis]
#     106 #             print("img after reszie:", im.dtype)
#     107 #             print("mask after resize: ", mask.dtype)
#
# error: OpenCV(4.1.0) C:\projects\opencv-python\opencv\modules\imgproc\src\resize.cpp:3718: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'

# %%
predictions = model.predict(test_img, steps = 1, verbose = 1) # NOTE THAT the input values should be normalized to be between 0 and 1
# Out:
# 1/1 [==============================] - 0s 119ms/step

# %%
for i in range(predictions.shape[0]):
    img = predictions[i][:,:,0]
    img = np.trunc(img*255)
    img = img.astype(np.uint8)
    plt.imshow(img, cmap= 'Greys')
    plt.show()
#     plt.imshow(Y_train[i][:,:,0], cmap = 'Greys')
    plt.show()
