# %% [markdown]
# ### Model (Without ResNet)
# * Moderate downsampling
# * Skip connections for concatenation
# * RELU + Batch Norm
# * No RELU after each block output
# * Multi-scale feature extraction using ASPP similar network
# * Dilated Asymmetric Separable Convolutional layer

# %%
import sys
import random
import os
import warnings

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain

from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras import models
from keras import backend as K
from tensorflow.keras import callbacks
import glob

from PIL import Image
import glob

import tensorflow as tf
import time
import cv2
# Out:
# Using TensorFlow backend.

# %%
# !which python3
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    print("Name:", gpu.name, "  Type:", gpu.device_type)
# Out:
# /usr/bin/python3
# Name: /physical_device:GPU:0   Type: GPU

# %%
# Set some parameters
IMG_WIDTH = 512
IMG_HEIGHT = 512
IMG_CHANNELS = 3
#TRAIN_PATH = './dataset/training/'
#TEST_PATH = './dataset/testing/'
# TRAIN_NUM = 1700
# TEST_NUM = 300
sample_dir = "./train/img/"
mask_dir = "./train/mask/"
test_sample_dir = "./testing/sample/"
test_mask_dir = "./testing/mask/"

# %%
#Get the filenames of training and testing data
sample_ids = None
test_sample_ids = None
sample_ids = next(os.walk(sample_dir))[2]
test_sample_ids = next(os.walk(test_sample_dir))[2]
print(sample_ids[:10])
print(test_sample_ids[:10])
# Out:
# ['1803151818-00007601.png', '1803151818-00018027.png', '1803151818-00002588.png', '1803151818-00020594.png', '1803151818-00012341.png', '1803151818-00013603.png', '1803151818-00015026.png', '1803151818-00010138.png', '1803151818-00011274.png', '1803151818-00000936.png']
# ['00086.png', '00005.png', '00291.png', '00184.png', '00046.png', '00038.png', '00170.png', '00224.png', '00203.png', '00264.png']

# %%
def dilated_conv_block(input_tensor, num_filters):
    '''
    Number of filters (num_filters) : the number of input and output channels.
        the block doesn't change output shape
    
    NOTE
        set the the depth separable convolution's filter_num to different sizes
            and see how the parameters change.

    '''
    # Direct 1x1 convolution
    encoderONE = layers.Conv2D(int(num_filters/4), (1,1), padding = "same", use_bias=False)(input_tensor)
    encoderONE = layers.BatchNormalization()(encoderONE)
    encoderONE = layers.Activation('relu')(encoderONE)
    
    #1x1 convolution
    encoderTWO = layers.Conv2D(int(num_filters/2), (1,1), padding = "same", use_bias=False)(input_tensor)
    # 5x5 depthwise separable convolution stride 1 dilation_rate = 2
    encoderTWO = layers.SeparableConv2D(int(num_filters/4), (5,5), dilation_rate = 2, padding = "same", use_bias=False, depth_multiplier=2)(encoderTWO)
    encoderTWO = layers.BatchNormalization()(encoderTWO)
    encoderTWO = layers.Activation('relu')(encoderTWO)
    
    #1x1 convolution
    encoderTHR = layers.Conv2D(int(num_filters/2), (1,1), padding = "same", use_bias=False)(input_tensor)
    # 3x3 depthwise separable convolution stride 1 dilation_rate = 2
    encoderTHR = layers.SeparableConv2D(int(num_filters/4), (3,3), dilation_rate = 2, padding = "same", use_bias=False, depth_multiplier=2)(encoderTHR)
    encoderTHR = layers.BatchNormalization()(encoderTHR)
    encoderTHR = layers.Activation('relu')(encoderTHR)
    
    #1x1 convolution
    encoderFOUR = layers.Conv2D(int(num_filters/2), (1,1), padding = "same", use_bias=False)(input_tensor)
    # 5x5 depthwise separable convolution stride 1 dilation_rate = 2
    encoderFOUR = layers.SeparableConv2D(int(num_filters/4), (5,5), dilation_rate = 3, padding = "same", use_bias=False, depth_multiplier=2)(encoderFOUR)
    encoderFOUR = layers.BatchNormalization()(encoderFOUR)
    encoderFOUR = layers.Activation('relu')(encoderFOUR)
    
    encoderOUT = layers.concatenate([encoderFOUR,encoderTHR, encoderTWO, encoderONE], axis=-1)
    #Final 1x1 convolution with relu to make sure the output have the same channels as input
#     encoderOUT = layers.Conv2D(num_filters, (1,1), padding = "same", use_bias=False)(encoderOUT)
#     encoderOUT = layers.Activation("relu")(encoderOUT)

    return encoderOUT

def downsample_block(input_tensor, num_filters):
    
    #Store the input to this "max_pooling layer" for skip connections
    store_feature =  layers.Conv2D(int(num_filters/4), (1,1), padding = "same", use_bias=False)(input_tensor)
    
    encoder = layers.Conv2D(int(num_filters/2), (1,1), padding = "same", use_bias=False)(input_tensor)
    
    # 2x2 max_pooling with stride 2
    encoderONE = layers.MaxPooling2D((2, 2), strides=(2, 2))(input_tensor) #already have output dimension desired

    # 5x5 depthwise separable convolution stride = 2
    encoderTWO = layers.ZeroPadding2D(padding=(2, 2))(encoder) # zero-padding (2,2) to keep output dimension consistent
    encoderTWO = layers.SeparableConv2D(num_filters, (5,5), strides = 2, use_bias=False)(encoderTWO)
    encoderTWO = layers.BatchNormalization()(encoderTWO)
    encoderTWO = layers.Activation('relu')(encoderTWO)
    
    # 3x3 depthwise separable convolution stride = 2
    encoderTHR = layers.ZeroPadding2D(padding = (1,1))(encoder) # zero-padding (1,1) to keep output dimension consistent
    encoderTHR = layers.SeparableConv2D(num_filters, (3,3), strides = 2, use_bias=False)(encoderTHR)
    encoderTHR = layers.BatchNormalization()(encoderTHR)
    encoderTHR = layers.Activation('relu')(encoderTHR) 

    
    # 7x7 depthwise separable convolution stride = 2
    encoderFOUR = layers.ZeroPadding2D(padding=(3, 3))(encoder) # zero-padding (3,3)to keep output dimension consistent
    encoderFOUR = layers.SeparableConv2D(num_filters, (7,7), strides = 2, use_bias=False)(encoderFOUR)
    encoderFOUR = layers.BatchNormalization()(encoderFOUR)
    encoderFOUR = layers.Activation('relu')(encoderFOUR)
 
    #By now the encoderOUT has shape reduced to 1/2 of input shape
    encoderOUT = layers.concatenate([encoderFOUR, encoderTHR, encoderTWO, encoderONE], axis=-1)
    #Final 1x1 convolution with relu to make sure the output have 2 times channels as input
    encoderOUT = layers.Conv2D(num_filters*2, (1,1), padding = "same", use_bias=False)(encoderOUT)
    encoderOUT = layers.Activation("relu")(encoderOUT)
    
    return store_feature, encoderOUT

def decoder_block(input_tensor, concat_tensor, num_filters):
    
    decoder = layers.Conv2DTranspose(num_filters, (2, 2), strides=(2, 2), padding='same')(input_tensor)
    
    decoder = layers.concatenate([concat_tensor, decoder], axis=-1)
    decoder = layers.BatchNormalization()(decoder)
    decoder = layers.Activation('relu')(decoder)
    
    decoder = layers.SeparableConv2D(num_filters, (3, 3), padding='same')(decoder)
    decoder = layers.BatchNormalization()(decoder)
    decoder = layers.Activation('relu')(decoder)
    
#     decoder = layers.SeparableConv2D(num_filters, (3, 3), padding='same')(decoder)
#     decoder = layers.BatchNormalization()(decoder)
#     decoder = layers.Activation('relu')(decoder)
    return decoder

# %%
img_shape = (IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)
print(img_shape)

inputs = layers.Input(shape=img_shape)
initial_block_2 = layers.MaxPool2D((2,2), strides = 2)(inputs)

#Now modify the inputs
initial_block_1 = layers.ZeroPadding2D(padding = (1,1))(inputs)
initial_block_1 = layers.Conv2D(29, (3,3), strides = 2, use_bias = False)(initial_block_1)

initial_block = layers.concatenate([initial_block_1, initial_block_2], axis = -1)

# 256
encoder0 = dilated_conv_block(initial_block, 32)
encoder0, encoder0_pool = downsample_block(encoder0, 32)

# 128
encoder1 = dilated_conv_block(encoder0_pool, 64)
encoder1, encoder1_pool = downsample_block(encoder1, 64)

# 64
encoder2 = dilated_conv_block(encoder1_pool, 128)
encoder2, encoder2_pool = downsample_block(encoder2, 128)

# 32
encoder3 = dilated_conv_block(encoder2_pool, 256)
encoder3, encoder3_pool = downsample_block(encoder3, 256)

# 16
# encoder4 = dilated_conv_block(encoder3_pool, 512)
# encoder4, encoder4_pool = downsample_block(encoder4, 512)

# 8
center = dilated_conv_block(encoder3_pool, 512)
center = dilated_conv_block(center, 512)

# center


# 16
decoder3 = decoder_block(center, encoder3, 256)
# 32
decoder2 = decoder_block(decoder3, encoder2, 128)
# 64
decoder1 = decoder_block(decoder2, encoder1, 64)
# 128
decoder0 = decoder_block(decoder1, encoder0, 32)
# 256
final = layers.UpSampling2D((2,2), interpolation= "bilinear")(decoder0)
outputs = layers.Conv2D(1, (1, 1), activation='sigmoid')(final)

model = None
model = models.Model(inputs=[inputs], outputs=[outputs])

model.summary()
# Out:
# (512, 512, 3)
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 512, 512, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d_13 (ZeroPadding2 (None, 514, 514, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 256, 256, 29) 783         zero_padding2d_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 256, 256, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 256, 256, 32) 0           conv2d_38[0][0]
#                                                                  max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 256, 256, 16) 512         concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 256, 256, 16) 512         concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 256, 256, 16) 512         concatenate_15[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_36 (SeparableC (None, 256, 256, 8)  1056        conv2d_42[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_35 (SeparableC (None, 256, 256, 8)  544         conv2d_41[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_34 (SeparableC (None, 256, 256, 8)  1056        conv2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 256, 256, 8)  256         concatenate_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 256, 256, 8)  32          separable_conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 256, 256, 8)  32          separable_conv2d_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 256, 256, 8)  32          separable_conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 256, 256, 8)  32          conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 256, 256, 8)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 256, 256, 8)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 256, 256, 8)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 256, 256, 8)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 256, 256, 32) 0           activation_51[0][0]
#                                                                  activation_50[0][0]
#                                                                  activation_49[0][0]
#                                                                  activation_48[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 256, 256, 16) 512         concatenate_16[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_16 (ZeroPadding2 (None, 262, 262, 16) 0           conv2d_44[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_15 (ZeroPadding2 (None, 258, 258, 16) 0           conv2d_44[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_14 (ZeroPadding2 (None, 260, 260, 16) 0           conv2d_44[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_39 (SeparableC (None, 128, 128, 32) 1296        zero_padding2d_16[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_38 (SeparableC (None, 128, 128, 32) 656         zero_padding2d_15[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_37 (SeparableC (None, 128, 128, 32) 912         zero_padding2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 128, 128, 32) 128         separable_conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 128, 128, 32) 128         separable_conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 128, 128, 32) 128         separable_conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 128, 128, 32) 0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 128, 128, 32) 0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 128, 128, 32) 0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 128, 128, 32) 0           concatenate_16[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 128, 128, 128 0           activation_54[0][0]
#                                                                  activation_53[0][0]
#                                                                  activation_52[0][0]
#                                                                  max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 128, 128, 64) 8192        concatenate_17[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 128, 128, 64) 0           conv2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 128, 128, 32) 2048        activation_55[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 128, 128, 32) 2048        activation_55[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 128, 128, 32) 2048        activation_55[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_42 (SeparableC (None, 128, 128, 16) 2624        conv2d_49[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_41 (SeparableC (None, 128, 128, 16) 1600        conv2d_48[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_40 (SeparableC (None, 128, 128, 16) 2624        conv2d_47[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 128, 128, 16) 1024        activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 128, 128, 16) 64          separable_conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 128, 128, 16) 64          separable_conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 128, 128, 16) 64          separable_conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 128, 128, 16) 64          conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 128, 128, 16) 0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 128, 128, 16) 0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 128, 128, 16) 0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 128, 128, 16) 0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 128, 128, 64) 0           activation_59[0][0]
#                                                                  activation_58[0][0]
#                                                                  activation_57[0][0]
#                                                                  activation_56[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 128, 128, 32) 2048        concatenate_18[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_19 (ZeroPadding2 (None, 134, 134, 32) 0           conv2d_51[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_18 (ZeroPadding2 (None, 130, 130, 32) 0           conv2d_51[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_17 (ZeroPadding2 (None, 132, 132, 32) 0           conv2d_51[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_45 (SeparableC (None, 64, 64, 64)   3616        zero_padding2d_19[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_44 (SeparableC (None, 64, 64, 64)   2336        zero_padding2d_18[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_43 (SeparableC (None, 64, 64, 64)   2848        zero_padding2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 64, 64, 64)   256         separable_conv2d_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 64, 64, 64)   256         separable_conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 64, 64, 64)   256         separable_conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 64, 64, 64)   0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 64, 64, 64)   0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 64, 64, 64)   0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 64, 64, 64)   0           concatenate_18[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 64, 64, 256)  0           activation_62[0][0]
#                                                                  activation_61[0][0]
#                                                                  activation_60[0][0]
#                                                                  max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 64, 64, 128)  32768       concatenate_19[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 64, 64, 128)  0           conv2d_52[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 64, 64, 64)   8192        activation_63[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 64, 64, 64)   8192        activation_63[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 64, 64, 64)   8192        activation_63[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_48 (SeparableC (None, 64, 64, 32)   7296        conv2d_56[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_47 (SeparableC (None, 64, 64, 32)   5248        conv2d_55[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_46 (SeparableC (None, 64, 64, 32)   7296        conv2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 64, 64, 32)   4096        activation_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 64, 64, 32)   128         separable_conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 64, 64, 32)   128         separable_conv2d_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 64, 64, 32)   128         separable_conv2d_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 64, 64, 32)   128         conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 64, 64, 32)   0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 64, 64, 32)   0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 64, 64, 32)   0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 64, 64, 32)   0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 64, 64, 128)  0           activation_67[0][0]
#                                                                  activation_66[0][0]
#                                                                  activation_65[0][0]
#                                                                  activation_64[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 64, 64, 64)   8192        concatenate_20[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_22 (ZeroPadding2 (None, 70, 70, 64)   0           conv2d_58[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_21 (ZeroPadding2 (None, 66, 66, 64)   0           conv2d_58[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_20 (ZeroPadding2 (None, 68, 68, 64)   0           conv2d_58[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_51 (SeparableC (None, 32, 32, 128)  11328       zero_padding2d_22[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_50 (SeparableC (None, 32, 32, 128)  8768        zero_padding2d_21[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_49 (SeparableC (None, 32, 32, 128)  9792        zero_padding2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 32, 32, 128)  512         separable_conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 32, 32, 128)  512         separable_conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 32, 32, 128)  512         separable_conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 32, 32, 128)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 32, 32, 128)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 32, 32, 128)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 32, 32, 128)  0           concatenate_20[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 32, 32, 512)  0           activation_70[0][0]
#                                                                  activation_69[0][0]
#                                                                  activation_68[0][0]
#                                                                  max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 32, 32, 256)  131072      concatenate_21[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 32, 32, 256)  0           conv2d_59[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 32, 32, 128)  32768       activation_71[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 32, 32, 128)  32768       activation_71[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 32, 32, 128)  32768       activation_71[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_54 (SeparableC (None, 32, 32, 64)   22784       conv2d_63[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_53 (SeparableC (None, 32, 32, 64)   18688       conv2d_62[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_52 (SeparableC (None, 32, 32, 64)   22784       conv2d_61[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 32, 32, 64)   16384       activation_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 32, 32, 64)   256         separable_conv2d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 32, 32, 64)   256         separable_conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 32, 32, 64)   256         separable_conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 32, 32, 64)   256         conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 32, 32, 64)   0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 32, 32, 64)   0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 32, 32, 64)   0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 32, 32, 64)   0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 32, 32, 256)  0           activation_75[0][0]
#                                                                  activation_74[0][0]
#                                                                  activation_73[0][0]
#                                                                  activation_72[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 32, 32, 128)  32768       concatenate_22[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_25 (ZeroPadding2 (None, 38, 38, 128)  0           conv2d_65[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_24 (ZeroPadding2 (None, 34, 34, 128)  0           conv2d_65[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_23 (ZeroPadding2 (None, 36, 36, 128)  0           conv2d_65[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_57 (SeparableC (None, 16, 16, 256)  39040       zero_padding2d_25[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_56 (SeparableC (None, 16, 16, 256)  33920       zero_padding2d_24[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_55 (SeparableC (None, 16, 16, 256)  35968       zero_padding2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 16, 16, 256)  1024        separable_conv2d_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 16, 16, 256)  1024        separable_conv2d_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 16, 16, 256)  1024        separable_conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 16, 16, 256)  0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 16, 16, 256)  0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 16, 16, 256)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 16, 16, 256)  0           concatenate_22[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 16, 16, 1024) 0           activation_78[0][0]
#                                                                  activation_77[0][0]
#                                                                  activation_76[0][0]
#                                                                  max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 16, 16, 512)  524288      concatenate_23[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 16, 16, 512)  0           conv2d_66[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 16, 16, 256)  131072      activation_79[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 16, 16, 256)  131072      activation_79[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 16, 16, 256)  131072      activation_79[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_60 (SeparableC (None, 16, 16, 128)  78336       conv2d_70[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_59 (SeparableC (None, 16, 16, 128)  70144       conv2d_69[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_58 (SeparableC (None, 16, 16, 128)  78336       conv2d_68[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 16, 16, 128)  65536       activation_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 16, 16, 128)  512         separable_conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 16, 16, 128)  512         separable_conv2d_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 16, 16, 128)  512         separable_conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 16, 16, 128)  512         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 16, 16, 128)  0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 16, 16, 128)  0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 16, 16, 128)  0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 16, 16, 128)  0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 16, 16, 512)  0           activation_83[0][0]
#                                                                  activation_82[0][0]
#                                                                  activation_81[0][0]
#                                                                  activation_80[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 16, 16, 256)  131072      concatenate_24[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 16, 16, 256)  131072      concatenate_24[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 16, 16, 256)  131072      concatenate_24[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_63 (SeparableC (None, 16, 16, 128)  78336       conv2d_74[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_62 (SeparableC (None, 16, 16, 128)  70144       conv2d_73[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_61 (SeparableC (None, 16, 16, 128)  78336       conv2d_72[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 16, 16, 128)  65536       concatenate_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 16, 16, 128)  512         separable_conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 16, 16, 128)  512         separable_conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 16, 16, 128)  512         separable_conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 16, 16, 128)  512         conv2d_71[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 16, 16, 128)  0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 16, 16, 128)  0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 16, 16, 128)  0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 16, 16, 128)  0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 16, 16, 512)  0           activation_87[0][0]
#                                                                  activation_86[0][0]
#                                                                  activation_85[0][0]
#                                                                  activation_84[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 32, 32, 64)   16384       concatenate_22[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 32, 32, 256)  524544      concatenate_25[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 32, 32, 320)  0           conv2d_64[0][0]
#                                                                  conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 32, 32, 320)  1280        concatenate_26[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 32, 32, 320)  0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_64 (SeparableC (None, 32, 32, 256)  85056       activation_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 32, 32, 256)  1024        separable_conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 32, 32, 256)  0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 64, 64, 32)   4096        concatenate_20[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 64, 64, 128)  131200      activation_89[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 64, 64, 160)  0           conv2d_57[0][0]
#                                                                  conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 64, 64, 160)  640         concatenate_27[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 64, 64, 160)  0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_65 (SeparableC (None, 64, 64, 128)  22048       activation_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 64, 64, 128)  512         separable_conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 64, 64, 128)  0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 128, 128, 16) 1024        concatenate_18[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 128, 128, 64) 32832       activation_91[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 128, 128, 80) 0           conv2d_50[0][0]
#                                                                  conv2d_transpose_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 128, 128, 80) 320         concatenate_28[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 128, 128, 80) 0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_66 (SeparableC (None, 128, 128, 64) 5904        activation_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 128, 128, 64) 256         separable_conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 128, 128, 64) 0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 256, 256, 8)  256         concatenate_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 256, 256, 32) 8224        activation_93[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, 256, 256, 40) 0           conv2d_43[0][0]
#                                                                  conv2d_transpose_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 256, 256, 40) 160         concatenate_29[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 256, 256, 40) 0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_67 (SeparableC (None, 256, 256, 32) 1672        activation_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 256, 256, 32) 128         separable_conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 256, 256, 32) 0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 512, 512, 32) 0           activation_95[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 512, 512, 1)  33          up_sampling2d_1[0][0]
# ==================================================================================================
# Total params: 3,357,528
# Trainable params: 3,349,480
# Non-trainable params: 8,048
# __________________________________________________________________________________________________

# %%
def dice_coeff(y_true, y_pred):
    smooth = 1.
    # Flatten
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    score = (2. * intersection + smooth) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth)
    return score

def dice_loss(y_true, y_pred):
    loss = 1 - dice_coeff(y_true, y_pred)
    return loss

def bce_dice_loss(y_true, y_pred):
    loss = losses.binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)
    return loss

# %%
def castF(x):
    return K.cast(x, K.floatx())

def castB(x):
    return K.cast(x, bool)

def iou_loss_core(true,pred):  #this can be used as a loss if you make it negative
    intersection = true * pred
    notTrue = 1 - true
    union = true + (notTrue * pred)

    return (K.sum(intersection, axis=-1) + K.epsilon()) / (K.sum(union, axis=-1) + K.epsilon())

def competitionMetric2(true, pred): #any shape can go - can't be a loss function

    tresholds = [0.5 + (i*.05)  for i in range(10)]

    #flattened images (batch, pixels)
    true = K.batch_flatten(true)
    pred = K.batch_flatten(pred)
    pred = castF(K.greater(pred, 0.5))

    #total white pixels - (batch,)
    trueSum = K.sum(true, axis=-1)
    predSum = K.sum(pred, axis=-1)

    #has mask or not per image - (batch,)
    true1 = castF(K.greater(trueSum, 1))    
    pred1 = castF(K.greater(predSum, 1))

    #to get images that have mask in both true and pred
    truePositiveMask = castB(true1 * pred1)

    #separating only the possible true positives to check iou
    testTrue = tf.boolean_mask(true, truePositiveMask)
    testPred = tf.boolean_mask(pred, truePositiveMask)

    #getting iou and threshold comparisons
    iou = iou_loss_core(testTrue,testPred) 
    truePositives = [castF(K.greater(iou, tres)) for tres in tresholds]

    #mean of thressholds for true positives and total sum
    truePositives = K.mean(K.stack(truePositives, axis=-1), axis=-1)
    truePositives = K.sum(truePositives)

    #to get images that don't have mask in both true and pred
    trueNegatives = (1-true1) * (1 - pred1) # = 1 -true1 - pred1 + true1*pred1
    trueNegatives = K.sum(trueNegatives) 

    return (truePositives + trueNegatives) / castF(K.shape(true)[0])

# %%
save_model_path = './weights.hdf5'
cp = tf.keras.callbacks.ModelCheckpoint(filepath=save_model_path, monitor='val_loss', save_best_only=True, verbose=1)

# %%
# sample_dir = "../big_dataset/train/img/"
# mask_dir = "../big_dataset/train/mask/"
# test_sample_dir = "../big_dataset/test/img/"
# test_mask_dir = "../big_dataset/test/mask"

batch_size = 6

class DataGenerator(tf.keras.utils.Sequence):
#     'Generates data for Keras'
    def __init__(self, train_im_path=sample_dir,train_mask_path=mask_dir,
                 augmentations=None, batch_size=batch_size,img_size=512, n_channels=3, shuffle=True, mode="train"):
#         'Initialization'
        self.batch_size = batch_size
        self.train_im_paths = glob.glob(train_im_path+'*')
        
        self.train_im_path = train_im_path
        self.train_mask_path = train_mask_path

        self.img_size = img_size
        
        self.n_channels = n_channels
        self.shuffle = shuffle
        self.augment = augmentations
        self.mode = mode

        self.on_epoch_end()

    def __len__(self):
#         'Denotes the number of batches per epoch'
        return int(np.ceil(len(self.train_im_paths) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:min((index+1)*self.batch_size,len(self.train_im_paths))]

        # Find list of IDs
        list_IDs_im = [self.train_im_paths[k] for k in indexes]

        # Generate data
        X, y = self.data_generation(list_IDs_im)
        
#         for i in range(batch_size):
#             print("Img come out", X[i,150:160, 150:160])
            
        # First generate data
        #Then rescale them
 
        if self.augment is None:
            return X.astype(np.float32)/255,np.array(y).astype(np.float32)/255
        else:            
            im,mask = [],[]   
            for x,y in zip(X,y):
                augmented = self.augment(image=x, mask=y)
                aug_im = augmented['image']
                aug_mask = augmented['mask']
#                 print("augmented image data type:", aug_im.dtype)
#                 print("augmented mask data type:", aug_mask.dtype)
                im.append(augmented['image'])
                mask.append(augmented['mask'])
                
                return_im = np.array(im)
                return_mask = np.array(mask)
                return_im = return_im.astype(np.float32)/255
                return_mask = return_mask.astype(np.float32)/255
                
            return return_im, return_mask

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.train_im_paths))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def data_generation(self, list_IDs_im):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        # Initialization
        X = np.empty((len(list_IDs_im),self.img_size,self.img_size, self.n_channels))
        y = np.empty((len(list_IDs_im),self.img_size,self.img_size, 1))
        # Generate data
        for i, im_path in enumerate(list_IDs_im):
            
            im = cv2.imread(im_path)
            im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
            mask_path = im_path.replace(self.train_im_path,self.train_mask_path)
            if self.mode == "train":
                pass
            else:
                mask_path = mask_path[:-4]+"_matte.png"             
            mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
            
#             print("img data type:", im.dtype)
#             print("mask data type: ", mask.dtype)
#             print("img feed in: ", im[150:160, 150:160])
#             print("mask feed in: ", mask[150:160, 150:160])
            
            if len(im.shape)==2:
                print("shape before:", im.shape)
                im = np.repeat(im[...,None],3,2)
                print("shape after:",im.shape)
                
#             # Resize sample
            X[i,] = cv2.resize(im,(self.img_size,self.img_size))
#             X[i,] = resize(im,(800, 500))
            y[i,] = cv2.resize(mask,(self.img_size,self.img_size))[..., np.newaxis]
#             print("img after reszie:", im.dtype)
#             print("mask after resize: ", mask.dtype)

            #NOTE that after skimage.transform.resize, the pixel value range of
            #the mask is already between 0 and 1. No NEED TO DIVIDE by 255
            # BUT NOW USING cv2.resize(), the values are between 0 and 255
            y[y>64] = 255
            y[y <64] = 0
        
        return X,y

# %%
from albumentations import (
    Compose, HorizontalFlip, CLAHE, HueSaturationValue,
    RandomBrightness, RandomContrast, RandomGamma,OneOf,
    ToFloat, ShiftScaleRotate,GridDistortion, ElasticTransform, JpegCompression, HueSaturationValue,
    RGBShift, RandomBrightness, RandomContrast, Blur, MotionBlur, MedianBlur, GaussNoise,CenterCrop,
    IAAAdditiveGaussianNoise,GaussNoise,OpticalDistortion,RandomSizedCrop
)

AUGMENTATIONS_TRAIN = Compose([
    HorizontalFlip(p=0.7),
    OneOf([
        RandomGamma(gamma_limit=(90,100), p=0.5)
         ], p=0.6),
    OneOf([
        ElasticTransform(p =0.7),
        GridDistortion(num_steps=2, distort_limit=0.3,p=0.5),
#         OpticalDistortion(distort_limit=2, shift_limit=0.2),
        ], p=0.9)
#     ToFloat(max_value=1)
],p=1)


AUGMENTATIONS_TEST = Compose([
#     ToFloat(max_value=1)
],p=1)

# %%
a = DataGenerator(batch_size=10,shuffle=False, augmentations=AUGMENTATIONS_TRAIN)
gen_images,gen_masks = a.__getitem__(0)
max_images = 10
grid_width = 2

print()
print("-----------------------------------------")
print()
for i in range(10):
#     img = gen_images[i].astype(np.uint8)

    img = gen_images[i]
    gt = gen_masks[i]

    print(img.shape)
    print(gt.shape)
    
#     print("img dtype:")
#     print(img.dtype)
    
#     print("mask dtype:")
#     print(gt.dtype)
    
    
    plt.imshow(img)
#     print(img[200:230, 200:240])
    plt.show()

    plt.imshow(gt.squeeze(), cmap = "Greys")
#     print(gt.squeeze()[200:230, 200:240])
    plt.show()
# Out:
# -----------------------------------------
#
# (512, 512, 3)
# (512, 512, 1)
# (512, 512, 3)
# (512, 512, 1)
# (512, 512, 3)
# (512, 512, 1)
# (512, 512, 3)
# (512, 512, 1)
# (512, 512, 3)
# (512, 512, 1)
# (512, 512, 3)
# (512, 512, 1)
# (512, 512, 3)
# (512, 512, 1)
# (512, 512, 3)
# (512, 512, 1)
# (512, 512, 3)
# (512, 512, 1)
# (512, 512, 3)
# (512, 512, 1)

# %%
# Here the two generators are instantiated to fit in the model.fit_generator()
batchSize = 12
print(sample_dir)
print(mask_dir)
print(test_sample_dir)
print(test_mask_dir)
training_generator = DataGenerator(batch_size= batchSize, augmentations=AUGMENTATIONS_TRAIN,img_size=IMG_HEIGHT, mode = "train")

validation_generator = DataGenerator(batch_size=batchSize,train_im_path = test_sample_dir ,
                                     train_mask_path=test_mask_dir,
                                     augmentations=None,
                                     img_size=IMG_HEIGHT,
                                    mode = "test")
# Out:
# ./train/img/
# ./train/mask/
# ./testing/sample/
# ./testing/mask/

# %%
opt = tf.keras.optimizers.Adam(lr =0.002)
model.compile(optimizer=opt, loss=bce_dice_loss, metrics=[dice_loss, competitionMetric2])

# %%
model = models.load_model("./weights.hdf5", custom_objects={'bce_dice_loss': bce_dice_loss,
                                                           'dice_loss': dice_loss})

# %%
#already trained for 65 epochs

history = model.fit_generator(training_generator,
                    epochs=5,
                    validation_data = validation_generator,
                    callbacks=[cp],
                    verbose =1,
                    workers=8
                    )
# Out:
# Epoch 1/5
# 168/866 [====>.........................] - ETA: 12:14 - loss: 0.0414 - dice_loss: 0.0117
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:112: RuntimeWarning: invalid value encountered in greater
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:113: RuntimeWarning: invalid value encountered in less
# 865/866 [============================>.] - ETA: 0s - loss: 0.0425 - dice_loss: 0.0120
# Epoch 00001: val_loss improved from inf to 0.09049, saving model to ./weights.hdf5
# 866/866 [==============================] - 947s 1s/step - loss: 0.0425 - dice_loss: 0.0120 - val_loss: 0.0905 - val_dice_loss: 0.0215
# Epoch 2/5
# 865/866 [============================>.] - ETA: 0s - loss: 0.0421 - dice_loss: 0.0120
# Epoch 00002: val_loss did not improve from 0.09049
# 866/866 [==============================] - 862s 995ms/step - loss: 0.0421 - dice_loss: 0.0120 - val_loss: 0.1092 - val_dice_loss: 0.0255
# Epoch 3/5
# 865/866 [============================>.] - ETA: 0s - loss: 0.0423 - dice_loss: 0.0121
# Epoch 00003: val_loss did not improve from 0.09049
# 866/866 [==============================] - 863s 996ms/step - loss: 0.0424 - dice_loss: 0.0121 - val_loss: 0.1191 - val_dice_loss: 0.0246
# Epoch 4/5
# 865/866 [============================>.] - ETA: 0s - loss: 0.0403 - dice_loss: 0.0115
# Epoch 00004: val_loss did not improve from 0.09049
# 866/866 [==============================] - 854s 986ms/step - loss: 0.0403 - dice_loss: 0.0115 - val_loss: 0.1018 - val_dice_loss: 0.0216
# Epoch 5/5
# 865/866 [============================>.] - ETA: 0s - loss: 0.0401 - dice_loss: 0.0114
# Epoch 00005: val_loss improved from 0.09049 to 0.08746, saving model to ./weights.hdf5
# 866/866 [==============================] - 866s 999ms/step - loss: 0.0401 - dice_loss: 0.0114 - val_loss: 0.0875 - val_dice_loss: 0.0199

# %%
model.save("./v2_maybe_overfitting.hdf5")

# %%
test_generator = DataGenerator(batch_size=1,train_im_path = test_sample_dir ,
                                     train_mask_path=test_mask_dir,
                                     augmentations=None,
                                     img_size=IMG_HEIGHT,
                                    mode = "test")

# %%
test_img = np.zeros([10, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS])
test_mask = np.zeros([10, IMG_HEIGHT, IMG_WIDTH, 1])

for i in range(10):
    imgs, masks = test_generator.__getitem__(i)
    print(imgs.shape)
    print(masks.shape)
    
    img = imgs[0]
    mask = masks[0]
    plt.imshow(img)
    plt.show()
    plt.imshow(mask[:,:,0], cmap = "Greys")
    plt.show()
    test_img[i] = img
    test_mask[i] = mask
    
    
print(test_img.shape)
# Out:
# (1, 512, 512, 3)
# (1, 512, 512, 1)
# (1, 512, 512, 3)
# (1, 512, 512, 1)
# (1, 512, 512, 3)
# (1, 512, 512, 1)
# (1, 512, 512, 3)
# (1, 512, 512, 1)
# (1, 512, 512, 3)
# (1, 512, 512, 1)
# (1, 512, 512, 3)
# (1, 512, 512, 1)
# (1, 512, 512, 3)
# (1, 512, 512, 1)
# (1, 512, 512, 3)
# (1, 512, 512, 1)
# (1, 512, 512, 3)
# (1, 512, 512, 1)
# (1, 512, 512, 3)
# (1, 512, 512, 1)
# (10, 512, 512, 3)

# %%
predictions = model.predict(test_img, steps = 1, verbose = 1) # NOTE THAT the input values should be normalized to be between 0 and 1
# Out:
# 1/1 [==============================] - 0s 119ms/step

# %%
for i in range(predictions.shape[0]):
    img = predictions[i][:,:,0]
    img = np.trunc(img*255)
    img = img.astype(np.uint8)
    plt.imshow(img, cmap= 'Greys')
    plt.show()
#     plt.imshow(Y_train[i][:,:,0], cmap = 'Greys')
    plt.show()
