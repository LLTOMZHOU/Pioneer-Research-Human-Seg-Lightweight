# %%
import matplotlib.pyplot as plt
from skimage.io import imread, imshow, imread_collection, concatenate_images, imsave
from skimage.transform import resize
from skimage.morphology import label
import os
import numpy as np

# %%
# !ls
# Out:
# mask  sample  'Skimage Learning.ipynb'

# %%
mask_path = "./mask"
mask_names = os.listdir(mask_path)
print(mask_names[:10])
# Out:
# ['00228_matte.png', '00280_matte.png', '00049_matte.png', '00260_matte.png', '00251_matte.png', '00007_matte.png', '00278_matte.png', '00036_matte.png', '00282_matte.png', '00106_matte.png']

# %%
for name in mask_names:
    path = os.path.join(mask_path, name)
    mask = imread(path)
    print(mask.shape)
    print(mask.dtype)
    mask = np.expand_dims(mask, axis=2)
    print(mask.shape)
# Out:
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
# (800, 600)
# uint8
# (800, 600, 1)
